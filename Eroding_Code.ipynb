# %%
from IPython.utils.text import Path
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
from google.colab import drive
import os
# Importing required Packages
drive.mount("/content/drive")     # Connect Drive to Colab
img = cv2.imread("/content/drive/My Drive/tree.jpg")    # Reading the image from the google drive
cv2_imshow(img)  
kernel = np.ones((5,5), np.uint8)
image = cv2.erode(img, kernel)  
cv2_imshow(image)
# Out:
# Mounted at /content/drive
# <PIL.Image.Image image mode=RGB size=771x480 at 0x7FD6B74C3AD0>
# <PIL.Image.Image image mode=RGB size=771x480 at 0x7FD6A4215C50>
